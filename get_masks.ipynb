# %%
import cv2 as cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('4.png',0)
ret,thresh1 = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)

plt.imshow(thresh1,'gray',vmin=0,vmax=255)

# %%
import cv2
import numpy as np

## Read
img = cv2.imread("2.png")

## convert to hsv
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

## mask of green (36,25,25) ~ (86, 255,255)
# mask = cv2.inRange(hsv, (36, 25, 25), (86, 255,255))
mask = cv2.inRange(hsv, (36, 25, 25), (70, 255,255))

## slice the green
imask = mask>0
green = np.zeros_like(img, np.uint8)
green[imask] = img[imask]

## save 
cv2.imwrite("2_mask.png", mask)
# Out:
# True

# %%
import cv2
import numpy as np

## Read
img = cv2.imread("4.png")

## convert to hsv
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

## mask of green (36,25,25) ~ (86, 255,255)
# mask = cv2.inRange(hsv, (36, 25, 25), (86, 255,255))
mask = cv2.inRange(hsv, (36, 25, 25), (70, 255,255))

## slice the green
imask = mask>0
green = np.zeros_like(img, np.uint8)
green[imask] = img[imask]

## save 
cv2.imwrite("4_mask.png", mask)
# Out:
# True

# %%
import cv2
import numpy as np

## Read
img = cv2.imread("night_toRestore.png")

## convert to hsv
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

## mask of green (36,25,25) ~ (86, 255,255)
# mask = cv2.inRange(hsv, (36, 25, 25), (86, 255,255))
mask = cv2.inRange(hsv, (36, 100, 100), (60, 255,255))

## slice the green
imask = mask>0
green = np.zeros_like(img, np.uint8)
green[imask] = img[imask]

kernel = np.ones((2, 2), np.uint8)

img_dilation = cv2.dilate(mask, kernel, iterations=1)


## save 
cv2.imwrite("night_mask.png", img_dilation)
# Out:
# True
